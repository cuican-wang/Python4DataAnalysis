# %%
from bs4 import BeautifulSoup
import urllib.request

r = urllib.request.urlopen('http://www.indeed.com')
soup = BeautifulSoup(r,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Job Search | one search. all jobs. Indeed.com
#   </title>
#   <meta content="Click here to find millions of jobs from thousands of company web sites, job boards and newspapers. one search. all jobs. Indeed." name="description"/>
#   <meta content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml " name="keywords"/>
#   <link href="/" rel="canonical"/>
#   <link href="/m/" media="handheld" rel="alternate"/>
#   <link href="https://plus.google.com/113999236499154807366" rel="publisher"/>
#   <link href="android-app://com.indeed.android.jobsearch/http/www.indeed.com/m/" rel="alternate"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <style type="text/css">
# ...
